# %% [markdown]
# <a href="https://colab.research.google.com/github/jaiss69/datavisual69/blob/main/datasciprctl7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('/content/anime.csv')
data
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 12289    4.15      211
# 12290    4.28      183
# 12291    4.88      219
# 12292    4.98      175
# 12293    5.46      142
#
# [12294 rows x 7 columns]

# %%
data1=pd.read_excel('/content/anime.xlsx')
data1

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mping
img=mping.imread('/content/sunset.jpg')
plt.imshow(img)

# %%
import pandas as pd
data=pd.DataFrame({"Roll no":[10,11,12,13,14],"Name":["sam","sahil","priya","megha","Sachin"],"Marks":[67,78,89,76,90],"Class":["A","B","C","D","A"]})
print(data)
# Out:
#    Roll no    Name  Marks Class
# 0       10     sam     67     A
# 1       11   sahil     78     B
# 2       12   priya     89     C
# 3       13   megha     76     D
# 4       14  Sachin     90     A

# %%
data.isnull().sum()
# Out:
# Roll no    0
# Name       0
# Marks      0
# Class      0
# dtype: int64

# %%
data.describe()
# Out:
#          Roll no      Marks
# count   5.000000   5.000000
# mean   12.000000  80.000000
# std     1.581139   9.617692
# min    10.000000  67.000000
# 25%    11.000000  76.000000
# 50%    12.000000  78.000000
# 75%    13.000000  89.000000
# max    14.000000  90.000000

# %%
data.count()
# Out:
# Roll no    5
# Name       5
# Marks      5
# Class      5
# dtype: int64

# %%
data.describe(include="object")
# Out:
#        Name Class
# count     5     5
# unique    5     4
# top     sam     A
# freq      1     2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll no  5 non-null      int64
#  1   Name     5 non-null      object
#  2   Marks    5 non-null      int64
#  3   Class    5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 288.0+ bytes

# %%
data.nunique()
# Out:
# Roll no    5
# Name       5
# Marks      5
# Class      4
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data["Name"]
# Out:
# 0       sam
# 1     sahil
# 2     priya
# 3     megha
# 4    Sachin
# Name: Name, dtype: object

# %%
data["Name"].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Name, dtype: bool

# %%
data['Name'].value_counts()
# Out:
# sam       1
# sahil     1
# priya     1
# megha     1
# Sachin    1
# Name: Name, dtype: int64

# %%
data["Class"].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: Class, dtype: bool

# %%
data["Class"].value_counts()
# Out:
# A    2
# B    1
# C    1
# D    1
# Name: Class, dtype: int64

# %%
data["Marks"].mean()
# Out:
# 80.0

# %%
data["Marks"].var()
# Out:
# 92.5

# %%
correlation=data.corr()
# Out:
# <ipython-input-34-7f2487af4b08>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=data.corr()

# %%
import seaborn as sns
sns.heatmap(correlation,annot=True,fmt=".2f",cmap="cividis")
# Out:
# <Axes: >
